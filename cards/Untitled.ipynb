# %%
from card import Card
# from hand import Hand
import csv

with open('poker.txt', 'r') as f:
    hands = list(csv.reader(f, delimiter=' '))
    
player_hands = []
opponent_hands = []

for hand in hands:
    temp = []
    for card in hand[0:5]:
        new_card = Card(*card)
        temp.append(new_card)
        new_card.calculate_card_value()
    player_hands.append(temp)
    
    temp = []
    for card in hand[5:10]:
        new_card = Card(*card)
        new_card.calculate_card_value()
        temp.append(new_card)
    opponent_hands.append(temp)
        

print(opponent_hands)
# Out:
# [[Card(face='7', suit='D', card_value=7), Card(face='2', suit='S', card_value=2), Card(face='5', suit='D', card_value=5), Card(face='3', suit='S', card_value=3), Card(face='A', suit='C', card_value=14)], [Card(face='7', suit='C', card_value=7), Card(face='5', suit='H', card_value=5), Card(face='8', suit='D', card_value=8), Card(face='T', suit='D', card_value=10), Card(face='K', suit='S', card_value=13)], [Card(face='Q', suit='H', card_value=12), Card(face='T', suit='D', card_value=10), Card(face='J', suit='C', card_value=11), Card(face='2', suit='D', card_value=2), Card(face='8', suit='S', card_value=8)], [Card(face='9', suit='H', card_value=9), Card(face='4', suit='D', card_value=4), Card(face='J', suit='C', card_value=11), Card(face='K', suit='S', card_value=13), Card(face='J', suit='S', card_value=11)], [Card(face='A', suit='S', card_value=14), Card(face='K', suit='H', card_value=13), Card(face='4', suit='C', card_value=4), Card(face='A', suit='D', card_value=14), Card(face='4', suit='S', card_value=4)], [Card(face='8', suit='D', card_value=8), Card(face='3', suit='S', card_value=3), Card(face='5', suit='D', card_value=5), Card(face='5', suit='C', card_value=5), Card(face='A', suit='H', card_value=14)], [Card(face='3', suit='S', card_value=3), Card(face='Q', suit='H', card_value=12), Card(face='5', suit='S', card_value=5), Card(face='6', suit='S', card_value=6), Card(face='A', suit='S', card_value=14)], [Card(face='K', suit='C', card_value=13), Card(face='4', suit='C', card_value=4), Card(face='3', suit='H', card_value=3), Card(face='7', suit='S', card_value=7), Card(face='K', suit='S', card_value=13)], [Card(face='4', suit='C', card_value=4), Card(face='Q', suit='S', card_value=12), Card(face='Q', suit='C', card_value=12), Card(face='A', suit='C', card_value=14), Card(face='K', suit='H', card_value=13)], [Card(face='K', suit='D', card_value=13), Card(face='9', suit='D', card_value=9), Card(face='7', suit='C', card_value=7), Card(face='A', suit='S', card_value=14), Card(face='J', suit='S', card_value=11)], [Card(face='T', suit='S', card_value=10), Card(face='6', suit='D', card_value=6), Card(face='3', suit='S', card_value=3), Card(face='A', suit='S', card_value=14), Card(face='A', suit='C', card_value=14)], [Card(face='K', suit='C', card_value=13), Card(face='J', suit='D', card_value=11), Card(face='6', suit='C', card_value=6), Card(face='T', suit='S', card_value=10), Card(face='3', suit='C', card_value=3)], [Card(face='3', suit='D', card_value=3), Card(face='9', suit='H', card_value=9), Card(face='K', suit='C', card_value=13), Card(face='4', suit='H', card_value=4), Card(face='8', suit='S', card_value=8)], [Card(face='3', suit='S', card_value=3), Card(face='6', suit='D', card_value=6), Card(face='6', suit='S', card_value=6), Card(face='4', suit='H', card_value=4), Card(face='K', suit='C', card_value=13)], [Card(face='9', suit='S', card_value=9), Card(face='4', suit='S', card_value=4), Card(face='Q', suit='H', card_value=12), Card(face='4', suit='H', card_value=4), Card(face='J', suit='D', card_value=11)], [Card(face='T', suit='S', card_value=10), Card(face='8', suit='H', card_value=8), Card(face='Q', suit='D', card_value=12), Card(face='A', suit='C', card_value=14), Card(face='5', suit='C', card_value=5)], [Card(face='A', suit='D', card_value=14), Card(face='A', suit='S', card_value=14), Card(face='8', suit='H', card_value=8), Card(face='2', suit='H', card_value=2), Card(face='Q', suit='S', card_value=12)], [Card(face='Q', suit='H', card_value=12), Card(face='T', suit='C', card_value=10), Card(face='6', suit='D', card_value=6), Card(face='7', suit='D', card_value=7), Card(face='9', suit='D', card_value=9)], [Card(face='9', suit='S', card_value=9), Card(face='9', suit='D', card_value=9), Card(face='9', suit='C', card_value=9), Card(face='A', suit='C', card_value=14), Card(face='3', suit='D', card_value=3)], [Card(face='3', suit='D', card_value=3), Card(face='2', suit='D', card_value=2), Card(face='T', suit='D', card_value=1 ...
